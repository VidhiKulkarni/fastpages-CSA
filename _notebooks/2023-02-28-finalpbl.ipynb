// %% [markdown]
// # Final PBL Blog
// > Final PBL Blog
//
// - toc: true
// - badges: true
// - comments: true
// - categories: [fastpages, jupyter, ap exam unit]

// %% [markdown]
// This week, I worked on the Notes Page and Log Page Primarily. The Notes page allows the user to log in to the website and then type in a note. The note will then save under the user's name and display on the page.
//
// This week, I also worked on the Backend of the Log Page. On the Log Page, it allows the user to save the ciphers that they have encrypted/decrypted.
//
// ![image.png](attachment:image.png)
